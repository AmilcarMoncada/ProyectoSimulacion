# %% [markdown]
# # Proyecto Teoría de la Simulación

# %% [markdown]
# # Amílcar José Moncada
# # 20211002386

# %% [markdown]
# ## Trabajaré en un Dataset el cual habla del rendimiento de estudiantes en examenes

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
from scipy.stats import truncnorm

# %%
dataframe = pd.read_csv('studentsperformanceinexams.csv')

# %%
dataframe
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# 0                 completed          67             67             63
# 1                      none          40             59             55
# 2                      none          59             60             50
# 3                      none          77             78             68
# 4                 completed          78             73             68
# ..                      ...         ...            ...            ...
# 995                    none          73             70             65
# 996               completed          85             91             92
# 997                    none          32             35             41
# 998                    none          73             74             82
# 999               completed          65             60             62
#
# [1000 rows x 8 columns]

# %% [markdown]
# ### El dataset contiene información como el genero, raza, nivel de educación de los padres, si el estudiante almuerza correctamente, si el estudiante a tomado un curso de preparación (todos los datos anteriores son categoricos) y por ultimo las notas en las clases de matematicas, lectura y escritura.

# %%
dataframe.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# ### Modificamos los nombres de las columnas para poder manipular las columnas de manera mas sencilla.

# %%
dataframe.columns = ["gender" , "group" , "par_edu" , "lunch" , "test" , "math" , "reading" , "writing"]

# %%
dataframe.head(2)
# Out:
#    gender    group           par_edu         lunch       test  math  reading  \
# 0    male  group A       high school      standard  completed    67       67
# 1  female  group D  some high school  free/reduced       none    40       59
#
#    writing
# 0       63
# 1       55

# %% [markdown]
# ### Almacenaremos de manera dinamica las columnas segun su tipo de dato

# %%
categoricos = []
numericos = []

for i in dataframe.columns:
    if dataframe[i].dtypes == 'int64':
        numericos.append(i)
    else:
        categoricos.append(i)

# %% [markdown]
# ##### Eliminare Lunch y el group (raza) ya que no es un valor que me es relevante, porque me quiero enfocar totalmente en la parte academica.

# %%
categoricos.remove("group")
categoricos.remove("lunch")

# %% [markdown]
# ### Campos Categoricos

# %%
categoricos
# Out:
# ['gender', 'par_edu', 'test']

# %% [markdown]
# ### Campos Numericos

# %%
numericos
# Out:
# ['math', 'reading', 'writing']

# %% [markdown]
# ### Agrupamos información para obtener las distribuciones estadisticas

# %%
frecuencias = (
    dataframe.groupby(categoricos, as_index=False).size()
)

# %%
frecuencias
# Out:
#     gender             par_edu       test  size
# 0   female  associate's degree  completed    27
# 1   female  associate's degree       none    54
# 2   female   bachelor's degree  completed    21
# 3   female   bachelor's degree       none    37
# 4   female         high school  completed    28
# 5   female         high school       none    66
# 6   female     master's degree  completed    12
# 7   female     master's degree       none    30
# 8   female        some college  completed    37
# 9   female        some college       none    63
# 10  female    some high school  completed    35
# 11  female    some high school       none    73
# 12    male  associate's degree  completed    48
# 13    male  associate's degree       none    74
# 14    male   bachelor's degree  completed    18
# 15    male   bachelor's degree       none    36
# 16    male         high school  completed    29
# 17    male         high school       none    79
# 18    male     master's degree  completed     7
# 19    male     master's degree       none    21
# 20    male        some college  completed    45
# 21    male        some college       none    77
# 22    male    some high school  completed    28
# 23    male    some high school       none    55

# %% [markdown]
# ### Guardamos el porcentaje

# %%
frecuencias["size"] = frecuencias["size"] / dataframe.shape[0]

# %%
frecuencias
# Out:
#     gender             par_edu       test   size
# 0   female  associate's degree  completed  0.027
# 1   female  associate's degree       none  0.054
# 2   female   bachelor's degree  completed  0.021
# 3   female   bachelor's degree       none  0.037
# 4   female         high school  completed  0.028
# 5   female         high school       none  0.066
# 6   female     master's degree  completed  0.012
# 7   female     master's degree       none  0.030
# 8   female        some college  completed  0.037
# 9   female        some college       none  0.063
# 10  female    some high school  completed  0.035
# 11  female    some high school       none  0.073
# 12    male  associate's degree  completed  0.048
# 13    male  associate's degree       none  0.074
# 14    male   bachelor's degree  completed  0.018
# 15    male   bachelor's degree       none  0.036
# 16    male         high school  completed  0.029
# 17    male         high school       none  0.079
# 18    male     master's degree  completed  0.007
# 19    male     master's degree       none  0.021
# 20    male        some college  completed  0.045
# 21    male        some college       none  0.077
# 22    male    some high school  completed  0.028
# 23    male    some high school       none  0.055

# %% [markdown]
# ### Ahora se identifica de manera dinamica los Upper Bound y Lower Bound

# %%
Upper_Lower = {}
columnas = []
for i in numericos:
    Upper_Lower[i] = [
        ( 'lower', lambda x: x.quantile(.25) - 1.5 * (x.quantile(.75) - x.quantile(.25) )),
        ( 'upper', lambda x: x.quantile(.75) + 1.5 * (x.quantile(.75) - x.quantile(.25) ))
    ]
    columnas.append(f"{i}_lower")
    columnas.append(f"{i}_upper")

dataframe_resultado = dataframe.groupby(categoricos, as_index= False).agg(Upper_Lower)

# %%
dataframe_resultado.columns = categoricos + columnas

# %%
dataframe_resultado
# Out:
#     gender             par_edu       test  math_lower  math_upper  \
# 0   female  associate's degree  completed      15.750     117.750
# 1   female  associate's degree       none      28.750     104.750
# 2   female   bachelor's degree  completed      24.000     112.000
# 3   female   bachelor's degree       none      25.500     109.500
# 4   female         high school  completed      26.125     103.125
# 5   female         high school       none      22.875      97.875
# 6   female     master's degree  completed      42.500     122.500
# 7   female     master's degree       none      24.875     113.875
# 8   female        some college  completed      24.000     104.000
# 9   female        some college       none      15.000     107.000
# 10  female    some high school  completed      21.750      99.750
# 11  female    some high school       none      11.500      95.500
# 12    male  associate's degree  completed      36.375     111.375
# 13    male  associate's degree       none      37.000     101.000
# 14    male   bachelor's degree  completed      54.125     115.125
# 15    male   bachelor's degree       none      33.125     112.125
# 16    male         high school  completed      46.500      98.500
# 17    male         high school       none      30.500     102.500
# 18    male     master's degree  completed      58.000     102.000
# 19    male     master's degree       none      26.000     114.000
# 20    male        some college  completed      33.000     113.000
# 21    male        some college       none      17.000     113.000
# 22    male    some high school  completed      21.250     107.250
# 23    male    some high school       none      33.500      97.500
#
#     reading_lower  reading_upper  writing_lower  writing_upper
# 0          35.500        119.500         42.000        118.000
# 1          35.500        109.500         31.250        109.250
# 2          32.500        124.500         32.000        128.000
# 3          32.500        116.500         34.000        114.000
# 4          34.000        116.000         35.500        121.500
# 5          28.375        105.375         28.875        103.875
# 6          43.125        134.125         59.375        124.375
# 7          30.125        121.125         32.625        119.625
# 8          37.500        113.500         37.000        117.000
# 9          31.500        107.500         27.000        115.000
# 10         35.250        105.250         43.250        101.250
# 11         32.000         96.000         18.000        106.000
# 12         43.875        106.875         46.375        103.375
# 13         28.000        100.000         29.500         95.500
# 14         49.000        111.000         48.000        120.000
# 15         23.000        113.000         20.250        114.250
# 16         39.000        103.000         45.000         93.000
# 17         32.000         96.000         23.250         93.250
# 18         61.250         95.250         48.250        106.250
# 19         28.500        104.500         30.500         98.500
# 20         47.500         99.500         39.000        103.000
# 21         13.500        105.500          7.500        107.500
# 22         20.875        105.875         12.375        109.375
# 23         22.250        100.250         17.250         99.250

# %% [markdown]
# ### Realizamos Join con los valores de los examenes con los Upper y Lower Bounds

# %%
dataframe_bound = dataframe.merge(
    dataframe_resultado
    , on = categoricos
    , how = "inner"
)

# %%
dataframe_bound
# Out:
#      gender    group             par_edu         lunch       test  math  \
# 0      male  group A         high school      standard  completed    67
# 1    female  group D    some high school  free/reduced       none    40
# 2      male  group E        some college  free/reduced       none    59
# 3      male  group B         high school      standard       none    77
# 4      male  group E  associate's degree      standard  completed    78
# ..      ...      ...                 ...           ...        ...   ...
# 995    male  group C         high school      standard       none    73
# 996    male  group D  associate's degree  free/reduced  completed    85
# 997  female  group C    some high school  free/reduced       none    32
# 998  female  group C        some college      standard       none    73
# 999    male  group A        some college      standard  completed    65
#
#      reading  writing  math_lower  math_upper  reading_lower  reading_upper  \
# 0         67       63      46.500      98.500         39.000        103.000
# 1         59       55      11.500      95.500         32.000         96.000
# 2         60       50      17.000     113.000         13.500        105.500
# 3         78       68      30.500     102.500         32.000         96.000
# 4         73       68      36.375     111.375         43.875        106.875
# ..       ...      ...         ...         ...            ...            ...
# 995       70       65      30.500     102.500         32.000         96.000
# 996       91       92      36.375     111.375         43.875        106.875
# 997       35       41      11.500      95.500         32.000         96.000
# 998       74       82      15.000     107.000         31.500        107.500
# 999       60       62      33.000     113.000         47.500         99.500
#
#      writing_lower  writing_upper
# 0           45.000         93.000
# 1           18.000        106.000
# 2            7.500        107.500
# 3           23.250         93.250
# 4           46.375        103.375
# ..             ...            ...
# 995         23.250         93.250
# 996         46.375        103.375
# 997         18.000        106.000
# 998         27.000        115.000
# 999         39.000        103.000
#
# [1000 rows x 14 columns]

# %% [markdown]
# ### De forma dinamica eliminamos los datos atipicos existentes (siguiendo de ejemplo la manera que se hizo en el video)

# %%
for i in numericos:
    print( f"Cantidad de {dataframe_bound.shape[0]} registros")
    print( f"Se esta procesando la columna {i}")

    dataframe_bound = dataframe_bound.loc[
        ( dataframe_bound[i] > dataframe_bound[f"{i}_lower"]) &
        ( dataframe_bound[i] < dataframe_bound[f"{i}_upper"]),:
    ]

print(f"Limpieza culminada correctamente, con una cantidad final de {dataframe_bound.shape[0]} registros")
# Out:
# Cantidad de 1000 registros
# Se esta procesando la columna math
# Cantidad de 995 registros
# Se esta procesando la columna reading
# Cantidad de 990 registros
# Se esta procesando la columna writing
# Limpieza culminada correctamente, con una cantidad final de 988 registros

# %%
porcentaje = (1 - dataframe_bound.shape[0]/1000)*100
print( f"Eliminamos un {porcentaje} % de los datos del dataset.")
# Out:
# Eliminamos un 1.200000000000001 % de los datos del dataset.

# %%
dataframe_bound
# Out:
#      gender    group             par_edu         lunch       test  math  \
# 0      male  group A         high school      standard  completed    67
# 1    female  group D    some high school  free/reduced       none    40
# 2      male  group E        some college  free/reduced       none    59
# 3      male  group B         high school      standard       none    77
# 4      male  group E  associate's degree      standard  completed    78
# ..      ...      ...                 ...           ...        ...   ...
# 995    male  group C         high school      standard       none    73
# 996    male  group D  associate's degree  free/reduced  completed    85
# 997  female  group C    some high school  free/reduced       none    32
# 998  female  group C        some college      standard       none    73
# 999    male  group A        some college      standard  completed    65
#
#      reading  writing  math_lower  math_upper  reading_lower  reading_upper  \
# 0         67       63      46.500      98.500         39.000        103.000
# 1         59       55      11.500      95.500         32.000         96.000
# 2         60       50      17.000     113.000         13.500        105.500
# 3         78       68      30.500     102.500         32.000         96.000
# 4         73       68      36.375     111.375         43.875        106.875
# ..       ...      ...         ...         ...            ...            ...
# 995       70       65      30.500     102.500         32.000         96.000
# 996       91       92      36.375     111.375         43.875        106.875
# 997       35       41      11.500      95.500         32.000         96.000
# 998       74       82      15.000     107.000         31.500        107.500
# 999       60       62      33.000     113.000         47.500         99.500
#
#      writing_lower  writing_upper
# 0           45.000         93.000
# 1           18.000        106.000
# 2            7.500        107.500
# 3           23.250         93.250
# 4           46.375        103.375
# ..             ...            ...
# 995         23.250         93.250
# 996         46.375        103.375
# 997         18.000        106.000
# 998         27.000        115.000
# 999         39.000        103.000
#
# [988 rows x 14 columns]

# %% [markdown]
# ### Quitamos las columnas de Lower y Upper, ya que despues de la impieza no las necesitamos

# %%
dataframe_clean = dataframe_bound.loc[ :, categoricos + numericos]

# %%
dataframe_clean
# Out:
#      gender             par_edu       test  math  reading  writing
# 0      male         high school  completed    67       67       63
# 1    female    some high school       none    40       59       55
# 2      male        some college       none    59       60       50
# 3      male         high school       none    77       78       68
# 4      male  associate's degree  completed    78       73       68
# ..      ...                 ...        ...   ...      ...      ...
# 995    male         high school       none    73       70       65
# 996    male  associate's degree  completed    85       91       92
# 997  female    some high school       none    32       35       41
# 998  female        some college       none    73       74       82
# 999    male        some college  completed    65       60       62
#
# [988 rows x 6 columns]

# %% [markdown]
# ### Preparación del resumen

# %%
summ_agregaciones = {}
columnas_agr = []

for i in numericos:
    summ_agregaciones[i] = ["min", "max", "mean", "std"]
    columnas_agr.append( f"{i}_min")
    columnas_agr.append( f"{i}_max")
    columnas_agr.append( f"{i}_mean")
    columnas_agr.append( f"{i}_std")

# %%
summ_agregaciones
# Out:
# {'math': ['min', 'max', 'mean', 'std'],
#  'reading': ['min', 'max', 'mean', 'std'],
#  'writing': ['min', 'max', 'mean', 'std']}

# %%
dataframe_summ = dataframe_clean.groupby( categoricos , as_index= False).agg(summ_agregaciones)

# %%
dataframe_summ.columns = categoricos + columnas_agr

# %%
dataframe_summ
# Out:
#     gender             par_edu       test  math_min  math_max  math_mean  \
# 0   female  associate's degree  completed        41        95  68.703704
# 1   female  associate's degree       none        32        92  66.867925
# 2   female   bachelor's degree  completed        43       100  69.047619
# 3   female   bachelor's degree       none        37        89  66.378378
# 4   female         high school  completed        43        90  65.571429
# 5   female         high school       none        30        93  60.378788
# 6   female     master's degree  completed        57       100  79.833333
# 7   female     master's degree       none        40        91  68.133333
# 8   female        some college  completed        26       100  63.694444
# 9   female        some college       none        38        91  63.475410
# 10  female    some high school  completed        33        92  61.878788
# 11  female    some high school       none        25        90  55.219178
# 12    male  associate's degree  completed        48       100  75.500000
# 13    male  associate's degree       none        38       100  69.148649
# 14    male   bachelor's degree  completed        61       100  84.058824
# 15    male   bachelor's degree       none        35       100  72.888889
# 16    male         high school  completed        53        89  71.413793
# 17    male         high school       none        40       100  67.714286
# 18    male     master's degree  completed        69        91  80.428571
# 19    male     master's degree       none        38        99  68.857143
# 20    male        some college  completed        46       100  74.159091
# 21    male        some college       none        30        97  64.623377
# 22    male    some high school  completed        40        97  64.857143
# 23    male    some high school       none        36        96  65.945455
#
#      math_std  reading_min  reading_max  reading_mean  reading_std  \
# 0   15.585533           56          100     77.888889    13.051181
# 1   13.334510           41          100     73.283019    12.504426
# 2   15.493470           53          100     79.809524    13.984345
# 3   13.433688           53          100     74.216216    12.277204
# 4   12.784332           48           96     75.250000    12.819617
# 5   14.268594           32          100     68.060606    14.726093
# 6   14.121765           68          100     86.916667    12.228568
# 7   14.214450           50          100     76.766667    14.277263
# 8   15.399108           44          100     75.333333    13.401492
# 9   13.679189           44          100     71.491803    12.964854
# 10  13.715314           43          100     72.212121    14.077370
# 11  15.186111           34           88     64.054795    13.877330
# 12  12.736213           54          100     75.804348    11.401013
# 13  13.056969           34           91     65.081081    11.935623
# 14  11.343889           70           97     82.235294     8.982827
# 15  16.065540           34           99     67.138889    16.092860
# 16   9.678833           56           87     71.172414     9.028008
# 17  13.476937           33           89     63.454545    12.624689
# 18   8.521681           66           93     78.714286     8.769536
# 19  15.496082           40           96     65.857143    13.705056
# 20  13.831113           51           97     73.318182    10.733067
# 21  15.419604           27           95     60.740260    15.631785
# 22  15.409747           37           87     63.535714    13.704506
# 23  14.044134           31           84     61.200000    13.326943
#
#     writing_min  writing_max  writing_mean  writing_std
# 0            53          100     80.444444    13.238444
# 1            39          100     71.811321    13.166181
# 2            60          100     81.857143    13.499206
# 3            48          100     74.513514    12.722730
# 4            53           97     77.428571    12.755329
# 5            35           96     65.696970    13.911777
# 6            74          100     90.166667     9.703170
# 7            44          100     77.300000    15.454382
# 8            46          100     77.083333    13.004120
# 9            47           96     70.918033    12.361628
# 10           45           97     73.363636    13.076262
# 11           28           91     62.054795    14.515213
# 12           52          100     75.630435    11.361453
# 13           36           90     62.702703    11.833004
# 14           65          100     83.470588    10.909386
# 15           33           97     66.166667    16.287594
# 16           49           86     68.862069     9.026644
# 17           30           87     59.064935    12.917081
# 18           65           97     79.000000    11.284207
# 19           41           96     64.666667    14.329457
# 20           47           95     72.409091    11.140369
# 21           24           88     57.064935    15.335149
# 22           39           90     62.000000    15.040686
# 23           27           82     57.690909    13.256547

# %% [markdown]
# ### Comenzamos el proceso de expansión del Dataset

# %%
expansión = 200000

# %%
valores = np.random.choice ( frecuencias.index, size=expansión, p=frecuencias["size"].to_list() )

# %%
def trunc(min, max, media, desv_std, size):
    a, b = (min - media) / desv_std, (max - media) / desv_std
    muestras = truncnorm.rvs( a, b, loc=media, scale=desv_std, size=size)
    return muestras

# %%
dataframe_extendido = pd.DataFrame()

for h in frecuencias.index:
    conf = {
        "valor": valores[valores == h]
    }
    for i in numericos:
        
        conf[i] = trunc(
            dataframe_summ.iloc[h][f"{i}_min"],
            dataframe_summ.iloc[h][f"{i}_max"],
            dataframe_summ.iloc[h][f"{i}_mean"],
            dataframe_summ.iloc[h][f"{i}_std"],
            len(valores[valores == h])
        )

    temporal = pd.DataFrame(conf)
    dataframe_extendido = pd.concat([dataframe_extendido, temporal])

# %%
dataframe_extendido
# Out:
#        valor       math    reading    writing
# 0          0  66.349095  97.457294  76.174302
# 1          0  71.368743  56.309546  61.556761
# 2          0  65.583542  86.954808  93.318983
# 3          0  68.947989  63.747881  61.391793
# 4          0  50.201269  71.653795  66.998794
# ...      ...        ...        ...        ...
# 10983     23  66.304101  35.895153  40.864774
# 10984     23  89.485592  81.926025  47.582048
# 10985     23  72.365068  36.425315  71.963164
# 10986     23  79.008101  62.386017  58.691082
# 10987     23  67.551415  54.785036  52.826310
#
# [200000 rows x 4 columns]

# %%
frecuencias["valor"] = frecuencias.index

# %%
frecuencias
# Out:
#     gender             par_edu       test   size  valor
# 0   female  associate's degree  completed  0.027      0
# 1   female  associate's degree       none  0.054      1
# 2   female   bachelor's degree  completed  0.021      2
# 3   female   bachelor's degree       none  0.037      3
# 4   female         high school  completed  0.028      4
# 5   female         high school       none  0.066      5
# 6   female     master's degree  completed  0.012      6
# 7   female     master's degree       none  0.030      7
# 8   female        some college  completed  0.037      8
# 9   female        some college       none  0.063      9
# 10  female    some high school  completed  0.035     10
# 11  female    some high school       none  0.073     11
# 12    male  associate's degree  completed  0.048     12
# 13    male  associate's degree       none  0.074     13
# 14    male   bachelor's degree  completed  0.018     14
# 15    male   bachelor's degree       none  0.036     15
# 16    male         high school  completed  0.029     16
# 17    male         high school       none  0.079     17
# 18    male     master's degree  completed  0.007     18
# 19    male     master's degree       none  0.021     19
# 20    male        some college  completed  0.045     20
# 21    male        some college       none  0.077     21
# 22    male    some high school  completed  0.028     22
# 23    male    some high school       none  0.055     23

# %%
dataframe_final = frecuencias.loc[: , ["valor"] + categoricos].merge(
    dataframe_extendido,
    on="valor",
    how="inner"
    )

# %%
dataframe_final = dataframe_final.drop(columns=["valor"])

# %%
dataframe_final
# Out:
#         gender             par_edu       test       math    reading    writing
# 0       female  associate's degree  completed  66.349095  97.457294  76.174302
# 1       female  associate's degree  completed  71.368743  56.309546  61.556761
# 2       female  associate's degree  completed  65.583542  86.954808  93.318983
# 3       female  associate's degree  completed  68.947989  63.747881  61.391793
# 4       female  associate's degree  completed  50.201269  71.653795  66.998794
# ...        ...                 ...        ...        ...        ...        ...
# 199995    male    some high school       none  66.304101  35.895153  40.864774
# 199996    male    some high school       none  89.485592  81.926025  47.582048
# 199997    male    some high school       none  72.365068  36.425315  71.963164
# 199998    male    some high school       none  79.008101  62.386017  58.691082
# 199999    male    some high school       none  67.551415  54.785036  52.826310
#
# [200000 rows x 6 columns]

# %% [markdown]
# ### Resumen estadistico del dataset original

# %%
dataframe_clean.describe()
# Out:
#              math     reading     writing
# count  988.000000  988.000000  988.000000
# mean    66.786437   69.368421   68.093117
# std     15.014344   14.417424   15.317294
# min     25.000000   27.000000   24.000000
# 25%     56.000000   60.000000   58.000000
# 50%     67.000000   70.000000   68.000000
# 75%     77.000000   79.000000   79.000000
# max    100.000000  100.000000  100.000000

# %% [markdown]
# ### Resumen estadistico del dataset simulado

# %%
dataframe_final.describe()
# Out:
#                 math        reading        writing
# count  200000.000000  200000.000000  200000.000000
# mean       66.683789      69.186519      67.867331
# std        13.657974      13.208054      13.989410
# min        25.013912      27.034426      24.040977
# 25%        57.129390      60.177881      58.290224
# 50%        66.985156      69.636096      68.250211
# 75%        76.525605      78.688947      77.952082
# max        99.996165      99.998491      99.994618

# %% [markdown]
# ##### Podemos observar que hemos realizado una simulación correcta dado que estamos teniendo un alto porcentaje de efectividad con lo cercanos que estan las cantidades obtenidas junto a las originales.

# %% [markdown]
# ##### Se observa tambien que el dataset original traia un numero bajo de valores atipicos (12) el cual facilitó el desarrollo del proyecto, tambien esto beneficia la simulación, ya que nos acerca aún mas a los valores que buscamos simular.
